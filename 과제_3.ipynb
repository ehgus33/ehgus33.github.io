# %% [markdown]
# 1. L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.

# %%
# !pip install IPython

# %%
from IPython.display import Image

# %%
Image("C:\dohyun\ProDesk\Desktop/shot1.jpg")

# %% [markdown]
# L=[1,2,3,4,5] 에서 L[1:3] 을 불렀을 때, 왼쪽그림에서 오른쪽그림처럼 된다고 한다면

# %%
# 1번
L=[1,2,3,4,5]

L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %%
Image("C:\dohyun\ProDesk\Desktop/shot2.jpg")

# %% [markdown]
# 슬라이싱을 할당할 때에는 객체를 할당하는 것이 아니라,
# 위 그림처럼 1-3이라는 부분이 오른쪽 [100] 의 0-1 부분을 할당하기 때문에 1번과 같은 결과가 나온다고 생각합니다.
#
# 그리고 슬라이싱을 할당할 때, 리스트의 길이에 상관없이 할당되는 이유가 위와 같은 이유라고 생각합니다.

# %%
# 2번
L=[1,2,3,4,5]

L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# (100)은 ()가 있어서 튜플처럼 보이지만 정수형으로
# [(100)] == [100] 이기 때문에 2번도 1번의 이유와 동일합니다.

# %%
[(100)] == [100]
# Out:
# True

# %%
# 3번
L=[1,2,3,4,5]

L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-315853700582> in <module>
#       2 L=[1,2,3,4,5]
#       3
# ----> 4 L[1:3] = 100
#       5 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# Error 코드 : iterable만 할당할 수 있다. 라고 합니다.
# iterable는 list, tuple, dict 와 같은 연속적인 데이터를 포함한 자료형들인데,
# 100은 int형 자료형이기 때문에 3번과 같은 결과가 나왔다고 생각합니다.

# %%
# 4번
L=[1,2,3,4,5]

L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-87841de84bcd> in <module>
#       2 L=[1,2,3,4,5]
#       3
# ----> 4 L[1:3] = (100)
#       5 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# (100) == 100 이므로, 4번도 3번과 같은 이유 입니다.

# %%
# 5번
L=[1,2,3,4,5]

L[1:3] = (100,101,102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 리스트의 1-3부분이 오른쪽 튜플의 0-3부분을 할당하기 때문에 5번과 같은 결과가 나왔습니다.

# %%
# 6번
L=[1,2,3,4,5]

L[1:3] = [100,101,102]
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 리스트의 1-3부분이 오른쪽 리스트의 0-3부분을 할당하기 때문에 6번과 같은 결과가 나왔습니다.

# %%
# 7번
L=[1,2,3,4,5]

L[1:3] = [(100,101,102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# 리스트의 1-3부분이 오른쪽 리스트의 0-1부분을 할당하고,
# 또, 오른쪽 리스트의 0-1부분은 튜플(100,101,102)를 할당하기 때문에 위와 같은 결과가 나왔습니다.

# %%
Image("C:\dohyun\ProDesk\Desktop/shot3.jpg")

# %%
# 8번
L=[1,2,3,4,5]

L[1:3] = [[100,101,102]]
print(L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# 리스트의 1-3부분이 오른쪽 리스트의 0-1부분을 할당하고,
# 또, 오른쪽 리스트의 0-1부분은 리스트[100,101,102]를 할당하기 때문에 위와 같은 결과가 나왔습니다.

# %% [markdown]
# 2. 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
# - 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
# - 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열  'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'

step_1 = ' '.join(S.split()[::-1])

print(step_1)
# Out:
# Python and World Hello

# %%
step_2 = ''.join(step_1.split())

print(step_2)
# Out:
# PythonandWorldHello

# %% [markdown]
# 3. 다음 코드를 보고 물음에 답하시오.
# a = [1, 2, 3]
# b = a * 3
# c = [a] * 3
# print(b)
# print(c)
#
# - 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오. // a[0]=0
#
# - 2) b와 c 객체의 차이는 무엇인가?

# %%
[1,2,2] * 3
# Out:
# [[1, 2, 2], [1, 2, 2], [1, 2, 2]]

# %%
a = [1,2,3]
b = a * 3
c = [a] * 3
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a[0]=0

# %%
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %%
print(a[0] is b[0])
print(b[0] is b[3])
# Out:
# False
# True

# %%
c[0] is a
# Out:
# True

# %% [markdown]
# b는 a 리스트[1,2,3]를 3번반복하는 것이 아닌 리스트 안에 인덱스가 가리키는 정수 객체 1,2,3을 3번 반복하고 새로운 리스트를 만드는것.
# 추가로, 위의 "a[0] is b[0]" 의 결과가 "False"로, 리스트a 안의 정수 객체를 복사해 새로운 객채를 만들고 그것을 3번 반복해서 리스트를 만드는 것으로 보임.

# %%
Image("C:\dohyun\ProDesk\Desktop/shot4.jpg")

# %% [markdown]
# c는 위의 "c[0] is a"  의 결과가 "True"로,
# a 리스트 자체를 3번 반복하고 새로운 리스트를 생성한 것이므로 a리스트의 원소값을 바꾸면 c도 역시 a리스트 자체를 3번 반복한 것이기 때문에 값이 바껴서 나온다.

# %%
Image("C:\dohyun\ProDesk\Desktop/shot5.jpg")

# %% [markdown]
# 4. 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#
# s = ' first star   :   second star   :    third star '
# l = ['first star', 'second star', 'third star']
#
# - 1) for ~ in 문을 이용한 코드를 작성하시오.
# - 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '

# %%
# 1) for문
s1 = s.split(':')

for i in range(len(s1)):
    s1[i] = s1[i].replace(' ','')

print(s1)

# 1-2) for문 2
# s1 = []

# for i in s.split(':'):
#     s1.append(i.replace(' ',''))

# print(s1)
# Out:
# ['firststar', 'secondstar', 'thirdstar']

# %%
# 2) 리스트 내포
s2 = s.split(':')

s2 = [i.replace(' ','') for i in s2]

print(s2)

# 2-2) 리스트 내포 2
# print([i.replace(' ','') for i in s.split(':')])
# Out:
# ['firststar', 'secondstar', 'thirdstar']

# %% [markdown]
# [해설]
# 문제에서 ':'을 기준으로 분리하여 리스트를 만들고, 이후에 공백을 제거하라고 이해하였기에,
# s1, s2 라는 분리한 리스트를 만들고 제거를 했습니다.
# - 1-2, 2-2는 추가로 코드를 짜본 것입니다.

# %% [markdown]
# 5. 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
# - 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#
# - 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#
# - [참고 1]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)
# - [참고 2]: sum() 등의 내장함수 사용 가능함

# %%
a = 0

# %%
#1) for ~ in 리터널

def addall(alist):    
    a = 0
    for i in alist:
        a = a + i
    return a

addall([1,2,3,4,5,6,7,8,9])
# Out:
# 45

# %%
#1) 리스트 내포
def addall(alist):
    return sum([i for i in alist])

addall([1,2,3,4,5,6,7,8,9])
# Out:
# 45

# %%
#2) for ~ in 리터널

def addallodd(alist):
    a = 0
    
    for i in alist:
        if i % 2 == 1: a += i
    
    return a

addallodd([1,2,3,4,5,6,7,8,9])
# Out:
# 25

# %%
#2) 리스트 내포

def addallodd(alist):
    return sum([i for i in alist if i % 2 == 1])

addallodd([1,2,3,4,5,6,7,8,9])
# Out:
# 25

# %% [markdown]
# 6. 다음 코드를 보고 물음에 답하시오.
#   L1 = [1, 2, 3]
#   L2 = [4, 5, 6]
#   d = {'low':L1, 'high':L2}
#   e = d
#   f = d.copy()
#   print(d)
#   print(e)
#   print(f)
#   print()
#   d['low'] = [10, 20, 30]
#   d['high'][1] = 500
#   print(d)
#   print(e)
#   print(f)
#
#
# - 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
# - 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print(d)
print(e)
print(f)
print()
d['low'] = [10, 20, 30]
d['high'][1] = 500
print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
#
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# 1)
# "e = d" 라는 것은 d가 할당하는 것을 e도 할당해라 라는 것으로,
# e와 d 모두 {'low':L1, 'high':L2} 라는 dict 자료형을 할당하므로 e와 d의 값은 항상 같다.

# %% [markdown]
# 2)
# f는 copy 함수를 써서 d와 똑같으면서 새로운 dict 자료형 객체를 만들고 그것을 할당하는 것으로,
# copy 함수로 복사를 하면 얇은 복사(shallow copy)로 dict "d['low']=[10,20,30]" 코드로 d가 가리키는 dict자료형의 low의 data가 [10,20,30]이라는 새로운 객체를 가리키는 것이므로,

# %% [markdown]
# 7. 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#
# - [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
# - 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}

# %%
# 1)
key_list = list(d.keys())
key_list.sort()

result = [(i,d[i]) for i in key_list]

print(result)
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]

# %%
# 2)
key_list = list(d.keys())
key_list.sort(reverse=True)

result = [(i,d[i]) for i in key_list]

print(result)
# Out:
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]

# %%
# 3)
key_list = list(d.values())
key_list.sort()

reverse_d = dict(map(reversed,d.items())) # 키와 값 뒤집기

result = [(reverse_d[i],i) for i in key_list]

print(result)
# Out:
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]

# %%
# 4)
key_list = list(d.values())
key_list.sort(reverse = True)

reverse_d = dict(map(reversed,d.items())) # 키와 값 뒤집기

result = [(reverse_d[i],i) for i in key_list]

print(result)
# Out:
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# 8. 다음 문제를 정확히 읽고 적합한 코딩을 제시하시오.
#  - length(X)를 다음과 같이 정의한다 : 10진수로 표현된 X의 자릿수
#  - Strange라는 숫자를 아래과 같이 정의한다.
#     - 음이 아닌 정수 중 자릿수가 1인 모든 숫자는 Strange이다.
#     - length(X) > 1 인 숫자 X 는 다음 2가지를 만족하면 Strange이다.
#         - X는 length(X)로 정확히 나누어 떨어진다.
#         - X / length(X) 가 strange이다.
#
#
#  - 이 문제에서 숫자 하나가 주어질 때, 이 숫자가 Strange인지 판단하는 함수 isStrange(num)을 작성하시오.
#  - isStrange(num) 함수가 재귀적인 함수가 되도록 작성해 보세요.

# %%
def length(X): 
    if X < 0: return len(str(X)) -1
    return len(str(X))


def isStrange(num):
    
    if length(num) == 1 and num < 0: return False
    
    elif num % length(num) != 0: return False
    
    elif length(num) != 1: isStrange(num / length(num))
        
    return True
    

num = 56
print(f"num = {num}                   =>   {isStrange(num)}")
# Out:
# num = 56                   =>   True

# %%
print(f"num = {0}                     =>   {isStrange(0)}")
print(f"num = {56}                    =>   {isStrange(56)}")
print(f"num = {100}                   =>   {isStrange(100)}")
print(f"num = {7882602506492313600}   =>   {isStrange(7882602506492313600)}")
print(f"num = {6012302549522098651}   =>   {isStrange(6012302549522098651)}")
# Out:
# num = 0                     =>   True
# num = 56                    =>   True
# num = 100                   =>   False
# num = 7882602506492313600   =>   True
# num = 6012302549522098651   =>   False

# %% [markdown]
# 9. 다음 문제를 정확히 읽고 적합한 코딩을 제시하시오.
#
# - 1번 그룹, 2번 그룹, ... n번 그룹으로 번호가 매겨진 총 n개의 그룹이 존재하고, ith 그룹에는 임의의 팀원 수 ai 명이 있다.
# 하나의 버스 정류장이 있고, 버스는 오직 한 대만 운영한다. 버스는 버스 정류장에 도착하고 모든 그룹은 버스를 통해 여행하길 원한다.
# 하지만, 같은 그룹에 속한 팀원들은 분리되기를 원치 않는다. 그래서 그룹의 모든 팀원이 탈 수 있을 때 에만 그 그룹은 버스에 탑승한다.
# 또한, 이들은 그룹의 번호순으로 여행을 하길 원한다. 예를 들어, 3번 그룹은 1번 그룹과 2번 그룹이 여행을 한 뒤에 버스를 탈 수 있거나, 1번 그룹과 2번 그룹이 이미 버스에 탑승한 상태에 있을 때 동시에 버스를 탈 수 있다.
# 마지막으로, 버스는 빈 좌석이 없을 때 에만 여행을 떠난다.
#
#
# - 이 문제에서 각 그룹의 팀원 수가 리스트로 주어질 때, 가능한 모든 버스의 사이즈 x(x명의 사람들이 동시에 탈 수 있음)를 반환하는 함수 solve(a) 를 작성하시오.
#
# - [주의] 반드시 계산 복잡도를 최대한 낮추세요. 아래 예시 3번을 실행했을 때 결과가 바로 나타날 수 있도록!!

# %%
# a = [1, 2, 1, 1, 1, 2, 1, 3]


a = [9999] * 10000
l = 0
n = 0
rr = []
nn = 0
aa = 0


for i in range(1, len(a)+1):
    n = i

    for j in range(0,len(a),i): # len() : 8
        ss = 0
        if len(a[j:j+i]) == n:
            if aa != sum(a[j:j+i]):
                aa = sum(a[j:j+i])
                print(aa, n)
            else : break
        else: break

        for k in range(len(a)):
            nn += 1
            ss += a[k]
            if ss < aa     : continue
            elif ss == aa  :
                if k == len(a)-1: pass
                else:
                    ss = 0
                    continue
            else           : break
        
            rr.append(aa)

print(rr)
print(nn)
# Out:
# 9999 1
# 19998 2
# 29997 3
# 39996 4
# 49995 5
# 59994 6
# 69993 7
# 79992 8
# 89991 9
# 99990 10
# 109989 11
# 119988 12
# 129987 13
# 139986 14
# 149985 15
# 159984 16
# 169983 17
# 179982 18
# 189981 19
# 199980 20
# 209979 21
# 219978 22
# 229977 23
# 239976 24
# 249975 25
# 259974 26
# 269973 27
# 279972 28
# 289971 29
# 299970 30
# 309969 31
# 319968 32
# 329967 33
# 339966 34
# 349965 35
# 359964 36
# 369963 37
# 379962 38
# 389961 39
# 399960 40
# 409959 41
# 419958 42
# 429957 43
# 439956 44
# 449955 45
# 459954 46
# 469953 47
# 479952 48
# 489951 49
# 499950 50
# 509949 51
# 519948 52
# 529947 53
# 539946 54
# 549945 55
# 559944 56
# 569943 57
# 579942 58
# 589941 59
# 599940 60
# 609939 61
# 619938 62
# 629937 63
# 639936 64
# 649935 65
# 659934 66
# 669933 67
# 679932 68
# 689931 69
# 699930 70
# 709929 71
# 719928 72
# 729927 73
# 739926 74
# 749925 75
# 759924 76
# 769923 77
# 779922 78
# 789921 79
# 799920 80
# 809919 81
# 819918 82
# 829917 83
# 839916 84
# 849915 85
# ...

# %% [markdown]
# ## [Incremental Project 문제]

# %%
# 요구사항 1

#1 URL 가져오기.
import requests

req = requests.get('http://cse.koreatech.ac.kr')
source = req.text

source = source.replace('\n','') # 들여쓰기 제거
source = source.replace('\t','') # Tap 제거
source = ' '.join(source.split()) # 중복 공백문자 제거

front_index, back_index, str_start, str_end = 0, 0, 0, 0

index = 0
str_list = []

switch = 1 # script 제거하기 위한 스위치 / 1 - On , 0 - Off

for i in source:
    
    #인지 부분
    if i == '<':
        front_index = index + 1      # < > 안의 문자확인을 위한 인덱스 저장
        
        # script 를 만나면 스위치=0 OFF
        if source[front_index : front_index + 6] == 'script': switch = 0
        elif source[front_index : front_index + 5] == 'style': switch = 0
        
        
    elif i == '>':
        back_index = index       # < > 안의 문자확인을 위한 인덱스 저장
        
        # /script, /style를 만나면 스위치=1 ON
        if source[back_index - 8 : back_index + 1] == '</script>': switch = 1
        elif source[back_index - 7 : back_index + 1] == '</style>': switch = 1
        
        elif switch == 1 : str_start = back_index + 1
        # 스위치 ON 이고 '>'만났기에 문자열 시작으로 그 때의 인덱스 저장    
    
    
    if str_start != 0 and i == '<':  # 스위치 0n 이고 '<' 만나면
        str_end = index # 문자열 끝이므로 그 때의 인덱스 저장
        
        #삽입 부분
        if source[str_start : str_end] != '' and source[str_start : str_end] != ' ':  # 비어있는 값 삭제
            str_list.append(source[str_start : str_end]) # 시작 인덱스 ~ 끝 인덱스
        
        #초기화
        str_start = 0
        str_end = 0        
    
    index += 1

    
# 추가 부분 : &lt ~ &gt 도 없애기
for s in str_list:
    if '&lt' in s:
        str_list.remove(s)

# %%
# 요구사항 2, 3
import string

p_list = list(string.punctuation)



# 구두문자 제거 부분
for i in range(len(str_list)):
    str_list[i] = str_list[i].translate(str.maketrans('','', string.punctuation))
    
true_str =[]
f_index = 0
    
#텍스트 문자열 -> 순수 텍스트 문자열
for str1 in str_list:
    switch = 1
    for i in range(len(str1)):
        if switch != 0 and str1[i] != ' ':
            f_index = i
            switch = 0
        
        elif str1[i] == ' ':
            true_str.append(str1[f_index:i])
            switch = 1
            
        if i == len(str1) - 1:
            true_str.append(str1[f_index:i+1])

# %%
# 잘 제거됬나 확인 / 아무것도 출력 안되면 없는 것.

for i in true_str:
    for j in range(len(i)):
        for k in p_list:
            if i[j] == k: print('구두문자 인덱스 -> ', true_str.index(i))
            elif i[j] == '': print("공백 인덱스 -> ", true_str.index(i))

# %%
str_list
# Out:
# ['403 Forbidden',
#  'Forbidden',
#  'You dont have permission to access this resource']

# %%
# 요구사항 4
str_dict = dict()

for i in range(len(true_str)):
    if true_str[i] not in str_dict: str_dict[true_str[i]] = 1
    else:
        str_dict[true_str[i]] = str_dict.get(true_str[i]) + 1
    
print(str_dict)
# Out:
# {'403': 1, 'Forbidden': 2, 'You': 1, 'dont': 1, 'have': 1, 'permission': 1, 'to': 1, 'access': 1, 'this': 1, 'resource': 1}

# %%
# 요구사항 1

#1 URL 가져오기.
import requests

req = requests.get('https://www.koreatech.ac.kr')
source = req.text

source = source.replace('\n','') # 들여쓰기 제거
source = source.replace('\t','') # Tap 제거
source = ' '.join(source.split()) # 중복 공백문자 제거

front_index, back_index, str_start, str_end = 0, 0, 0, 0

index = 0
str_list = []

switch = 1 # script 제거하기 위한 스위치 / 1 - On , 0 - Off

for i in source:
    
    #인지 부분
    if i == '<':
        front_index = index + 1      # < > 안의 문자확인을 위한 인덱스 저장
        
        # script 를 만나면 스위치=0 OFF
        if source[front_index : front_index + 6] == 'script': switch = 0
        elif source[front_index : front_index + 5] == 'style': switch = 0
        
        
    elif i == '>':
        back_index = index       # < > 안의 문자확인을 위한 인덱스 저장
        
        # /script, /style를 만나면 스위치=1 ON
        if source[back_index - 8 : back_index + 1] == '</script>': switch = 1
        elif source[back_index - 7 : back_index + 1] == '</style>': switch = 1
        
        elif switch == 1 : str_start = back_index + 1
        # 스위치 ON 이고 '>'만났기에 문자열 시작으로 그 때의 인덱스 저장    
    
    
    if str_start != 0 and i == '<':  # 스위치 0n 이고 '<' 만나면
        str_end = index # 문자열 끝이므로 그 때의 인덱스 저장
        
        #삽입 부분
        if source[str_start : str_end] != '' and source[str_start : str_end] != ' ':  # 비어있는 값 삭제
            str_list.append(source[str_start : str_end]) # 시작 인덱스 ~ 끝 인덱스
        
        #초기화
        str_start = 0
        str_end = 0        
    
    index += 1

    
# 추가 부분 : &lt ~ &gt 도 없애기
for s in str_list:
    if '&lt' in s:
        str_list.remove(s)

# 요구사항 2, 3
import string

p_list = list(string.punctuation)



# 구두문자 제거 부분
for i in range(len(str_list)):
    str_list[i] = str_list[i].translate(str.maketrans('','', string.punctuation))
    
true_str =[]
f_index = 0
    
#텍스트 문자열 -> 순수 텍스트 문자열
for str1 in str_list:
    switch = 1
    for i in range(len(str1)):
        if switch != 0 and str1[i] != ' ':
            f_index = i
            switch = 0
        
        elif str1[i] == ' ':
            true_str.append(str1[f_index:i])
            switch = 1
            
        if i == len(str1) - 1:
            true_str.append(str1[f_index:i+1])

# 요구사항 4
str_dict = dict()

for i in range(len(true_str)):
    if true_str[i] not in str_dict: str_dict[true_str[i]] = 1
    else:
        str_dict[true_str[i]] = str_dict.get(true_str[i]) + 1
    
print(str_dict)
# Out:
# {'한국기술교육대학교': 13, '닫기': 1, 'Link': 1, 'Link ': 1, 'Service': 1, '재학생': 3, '학생이': 4, '행복한': 4, '대학': 8, '온라인교육지원': 3, '생활관': 3, '원격지원': 2, '오늘의': 2, '식단': 2, '시설보수신청': 1, '학사종합시스템': 1, '인터넷증명발급': 3, '동아리안내': 2, '입학정보': 4, '코리아텍의': 4, '입학정보를': 4, '제공합니다': 8, '취업정보': 4, '최신': 4, '취업관련': 4, '정보를': 4, '예비대학생': 3, '입학안내': 3, '학부소개': 2, '언론기사': 2, '홍보영상물': 2, '장학제도': 2, '전화번호찾기': 2, '찾아오시는길': 3, '교직원': 3, '아우누리': 1, '무선랜신청': 1, '교육장비검색': 1, '일반인': 3, '코리아텍소개': 1, 'VISION2020': 2, 'PLUS': 2, '대학원소개': 1, '캠퍼스투어': 1, '코리아텍': 1, '특장점': 1, '자세히': 2, '보기': 2, '중앙일보대학평가‘교육중심대학’': 2, '1위': 4, '코리아텍은': 2, '중앙일보대학평가': 2, '11년': 2, '연속으로': 2, '연속으로 ': 2, '“교육중심대학': 2, '1위”': 2, '의': 2, '성과를': 2, '이루었습니다': 2, '스킵네비게이션': 1, '본문바로가기': 1, '주메뉴바로가기': 1, '통학·': 1, '셔틀버스': 1, '안전보건경영': 2, '웹메일': 3, '행정서비스헌장': 2, '부패행위신고': 1, '홈페이지': 1, '오류신고': 1, 'ENG': 2, 'CHI': 2, '팝업': 1, '팝업 ': 1, '0': 1, '건': 1, '전체메뉴열기': 1, '전체메뉴닫기': 1, '대학소개': 1, 'KOREATECH소개': 1, '교육목표': 1, '및': 2, '인재상': 1, '대학특성': 1, 'KOREATECH': 7
# ...

# %%
# 요구사항 1

#1 URL 가져오기.
import requests

req = requests.get('http://www.naver.com')
source = req.text

source = source.replace('\n','') # 들여쓰기 제거
source = source.replace('\t','') # Tap 제거
source = ' '.join(source.split()) # 중복 공백문자 제거

front_index, back_index, str_start, str_end = 0, 0, 0, 0

index = 0
str_list = []

switch = 1 # script 제거하기 위한 스위치 / 1 - On , 0 - Off

for i in source:
    
    #인지 부분
    if i == '<':
        front_index = index + 1      # < > 안의 문자확인을 위한 인덱스 저장
        
        # script 를 만나면 스위치=0 OFF
        if source[front_index : front_index + 6] == 'script': switch = 0
        elif source[front_index : front_index + 5] == 'style': switch = 0
        
        
    elif i == '>':
        back_index = index       # < > 안의 문자확인을 위한 인덱스 저장
        
        # /script, /style를 만나면 스위치=1 ON
        if source[back_index - 8 : back_index + 1] == '</script>': switch = 1
        elif source[back_index - 7 : back_index + 1] == '</style>': switch = 1
        
        elif switch == 1 : str_start = back_index + 1
        # 스위치 ON 이고 '>'만났기에 문자열 시작으로 그 때의 인덱스 저장    
    
    
    if str_start != 0 and i == '<':  # 스위치 0n 이고 '<' 만나면
        str_end = index # 문자열 끝이므로 그 때의 인덱스 저장
        
        #삽입 부분
        if source[str_start : str_end] != '' and source[str_start : str_end] != ' ':  # 비어있는 값 삭제
            str_list.append(source[str_start : str_end]) # 시작 인덱스 ~ 끝 인덱스
        
        #초기화
        str_start = 0
        str_end = 0        
    
    index += 1

    
# 추가 부분 : &lt ~ &gt 도 없애기
for s in str_list:
    if '&lt' in s:
        str_list.remove(s)

# 요구사항 2, 3
import string

p_list = list(string.punctuation)



# 구두문자 제거 부분
for i in range(len(str_list)):
    str_list[i] = str_list[i].translate(str.maketrans('','', string.punctuation))
    
true_str =[]
f_index = 0
    
#텍스트 문자열 -> 순수 텍스트 문자열
for str1 in str_list:
    switch = 1
    for i in range(len(str1)):
        if switch != 0 and str1[i] != ' ':
            f_index = i
            switch = 0
        
        elif str1[i] == ' ':
            true_str.append(str1[f_index:i])
            switch = 1
            
        if i == len(str1) - 1:
            true_str.append(str1[f_index:i+1])

# 요구사항 4
str_dict = dict()

for i in range(len(true_str)):
    if true_str[i] not in str_dict: str_dict[true_str[i]] = 1
    else:
        str_dict[true_str[i]] = str_dict.get(true_str[i]) + 1
    
print(str_dict)
# Out:
# {'NAVER': 4, '뉴스스탠드': 3, '바로가기': 7, '주제별캐스트': 1, '타임스퀘어': 2, '쇼핑캐스트': 1, '로그인': 2, 'whale': 1, '여러분의눈은': 1, '소중하니까': 1, '소중하니까 ': 1, '지금': 4, '바로': 9, '다크': 1, '모드를': 1, '켜세요': 1, '다운로드': 1, '3일': 1, '동안': 4, '보지': 1, '않기': 2, '네이버': 8, '네이버를': 1, '시작페이지로': 1, '쥬니어네이버': 1, '해피빈': 1, '검색': 2, '통합검색': 1, '블로그': 3, '카페': 2, '': 71, '카페명': 1, '카페글': 1, '지식iN': 2, '뉴스': 2, '사이트': 2, '카테고리': 1, '영화': 3, '웹문서': 1, '사전': 2, '백과사전': 1, '영어사전': 1, '영영사전': 1, '국어사전': 1, '일본어사전': 1, '한자사전': 1, '용어사전': 1, '책': 2, '음악': 1, '전문자료': 1, '쇼핑': 4, '지역': 2, '동영상': 1, '이미지': 1, '내PC': 1, '자동차': 2, '게임': 2, '건강': 2, '인물': 1, '긍정부정검색': 1, '한글': 1, '입력기': 1, '자동완성': 6, '레이어': 2, '최근검색어': 1, '전체삭제': 1, 'txt': 6, 'date': 2, '삭제': 1, '검색어': 2, '저장': 2, '기능이': 1, '꺼져': 1, '있습니다': 3, '설정이': 2, '초기화': 3, '된다면': 2, '된다면 ': 2, '도움말': 5, '을': 2, '확인해주세요': 2, '최근': 1, '내역이': 1, '없습니다': 2, '자동저장': 1, '끄기': 2, '5회차': 1, '당첨번호': 1, '추첨': 1, '13': 1, '지급기한': 1, '1년': 1, '6': 2, '7': 3, '8': 3, '9': 1, '10': 1, '11': 1, '
# ...

# %%
# 요구사항 1

#1 URL 가져오기.
import requests

req = requests.get('http://www.daum.net')
source = req.text

source = source.replace('\n','') # 들여쓰기 제거
source = source.replace('\t','') # Tap 제거
source = ' '.join(source.split()) # 중복 공백문자 제거

front_index, back_index, str_start, str_end = 0, 0, 0, 0

index = 0
str_list = []

switch = 1 # script 제거하기 위한 스위치 / 1 - On , 0 - Off

for i in source:
    
    #인지 부분
    if i == '<':
        front_index = index + 1      # < > 안의 문자확인을 위한 인덱스 저장
        
        # script 를 만나면 스위치=0 OFF
        if source[front_index : front_index + 6] == 'script': switch = 0
        elif source[front_index : front_index + 5] == 'style': switch = 0
        
        
    elif i == '>':
        back_index = index       # < > 안의 문자확인을 위한 인덱스 저장
        
        # /script, /style를 만나면 스위치=1 ON
        if source[back_index - 8 : back_index + 1] == '</script>': switch = 1
        elif source[back_index - 7 : back_index + 1] == '</style>': switch = 1
        
        elif switch == 1 : str_start = back_index + 1
        # 스위치 ON 이고 '>'만났기에 문자열 시작으로 그 때의 인덱스 저장    
    
    
    if str_start != 0 and i == '<':  # 스위치 0n 이고 '<' 만나면
        str_end = index # 문자열 끝이므로 그 때의 인덱스 저장
        
        #삽입 부분
        if source[str_start : str_end] != '' and source[str_start : str_end] != ' ':  # 비어있는 값 삭제
            str_list.append(source[str_start : str_end]) # 시작 인덱스 ~ 끝 인덱스
        
        #초기화
        str_start = 0
        str_end = 0        
    
    index += 1

    
# 추가 부분 : &lt ~ &gt 도 없애기
for s in str_list:
    if '&lt' in s:
        str_list.remove(s)

# 요구사항 2, 3
import string

p_list = list(string.punctuation)



# 구두문자 제거 부분
for i in range(len(str_list)):
    str_list[i] = str_list[i].translate(str.maketrans('','', string.punctuation))
    
true_str =[]
f_index = 0
    
#텍스트 문자열 -> 순수 텍스트 문자열
for str1 in str_list:
    switch = 1
    for i in range(len(str1)):
        if switch != 0 and str1[i] != ' ':
            f_index = i
            switch = 0
        
        elif str1[i] == ' ':
            true_str.append(str1[f_index:i])
            switch = 1
            
        if i == len(str1) - 1:
            true_str.append(str1[f_index:i+1])

# 요구사항 4
str_dict = dict()

for i in range(len(true_str)):
    if true_str[i] not in str_dict: str_dict[true_str[i]] = 1
    else:
        str_dict[true_str[i]] = str_dict.get(true_str[i]) + 1
    
print(str_dict)
# Out:
# {'Daum': 3, '주요': 2, '서비스': 5, '바로가기': 11, '오늘의': 5, '정보': 7, '미디어': 3, '실시간': 1, '이슈': 1, '멀티미디어': 2, '블로그': 4, '유익한': 2, '쇼핑': 3, '포토amp영상': 1, '웹': 1, '접근성': 1, '안내': 2, '자동실행': 1, '광고': 1, '설정': 1, '검색': 4, '통합': 1, '한글입력기': 1, '인기': 1, '검색어': 1, '코로나19': 1, '발생현황': 1, 'BTS': 1, '온라인콘서트': 1, '중고차판매': 1, '맛있는녀석들': 1, '윤보미': 1, '근조화환배달': 1, '사회적': 1, '거리두기': 1, '알렉볼드윈': 1, '오발사고': 1, '장기렌터카가격': 1, '희수': 1, '전소민': 1, '스티커제작': 1, 'gt다음': 1, '다음을': 1, '시작페이지로': 1, '카페': 4, '메일': 2, '뉴스': 6, '지도': 2, '증권': 1, '카카오TV': 2, '웹툰': 2, '브런치': 7, '사전': 1, '게임': 4, '같이가치': 3, '주요서비스': 1, '더보기': 3, '전체': 5, '커뮤니케이션': 1, '티스토리': 2, '카카오스토리': 2, '연예': 2, '스포츠': 2, '금융': 1, '부동산': 2, '자동차': 2, '쇼핑생활': 1, '선물하기': 2, '쇼핑라이브': 1, '쇼핑하우': 1, '메이커스': 1, '카카오헤어샵': 1, '카카오이모티콘샵': 1, '문화엔터': 1, '멜론': 1, '영화': 2, '카카오웹툰': 1, '카카오프렌즈': 1, '소셜임팩트': 1, '프로젝트100': 1, '사전지식': 1, '어학사전': 1, '번역': 1, '단어장': 1, '백과사전': 1, '배틀그라운드': 1, '패스': 1, '오브': 1, '엑자일': 1, '오딘': 1, '길찾기': 1, '로드뷰': 1, '버스정보': 1, '지하철노선도': 1,
# ...

# %%
str_list
# Out:
# ['Daum',
#  '주요 서비스 바로가기',
#  '오늘의 정보 바로가기',
#  '미디어 바로가기',
#  '실시간 이슈 바로가기',
#  '멀티미디어 바로가기',
#  '블로그 정보 바로가기',
#  '유익한 정보 바로가기',
#  '쇼핑 바로가기',
#  '오늘의 포토amp영상 바로가기',
#  '웹 접근성 안내',
#  '자동실행 광고 설정',
#  '검색',
#  '통합 검색',
#  '한글입력기',
#  '검색',
#  '인기 검색어',
#  '코로나19 발생현황',
#  'BTS 온라인콘서트',
#  '중고차판매',
#  '맛있는녀석들 윤보미',
#  '근조화환배달',
#  '사회적 거리두기',
#  '알렉볼드윈 오발사고',
#  '장기렌터카가격',
#  '희수 전소민',
#  '스티커제작',
#  'gt다음',
#  '다음을 시작페이지로',
#  '주요 서비스',
#  '카페',
#  '메일',
#  '뉴스',
#  '지도',
#  '증권',
#  '쇼핑',
#  '카카오TV',
#  '웹툰',
#  '블로그',
#  '브런치',
#  '사전',
#  '게임',
#  '같이가치',
#  '주요서비스',
#  '더보기',
#  '전체 서비스',
#  '커뮤니케이션',
#  '메일',
#  '카페',
#  '블로그',
#  '티스토리',
#  '브런치',
#  '카카오스토리',
#  '미디어',
#  '뉴스',
#  '연예',
#  '스포츠',
#  '금융',
#  '부동산',
#  '자동차',
#  '쇼핑생활',
#  '선물하기',
#  '쇼핑라이브',
#  '쇼핑하우',
#  '메이커스',
#  '카카오헤어샵',
#  '카카오이모티콘샵',
#  '문화엔터',
#  '멜론',
#  '영화',
#  '카카오웹툰',
#  '카카오TV',
#  '카카오프렌즈',
#  '소셜임팩트',
#  '같이가치',
#  '프로젝트100',
#  '사전지식',
#  '어학사전',
#  '번역',
#  '단어장',
#  '백과사전',
#  '게임',
# ...

# %%
# 요구사항 1

#1 URL 가져오기.
import requests

req = requests.get('http://www.nytimes.com')
source = req.text

source = source.replace('\n','') # 들여쓰기 제거
source = source.replace('\t','') # Tap 제거
source = ' '.join(source.split()) # 중복 공백문자 제거

front_index, back_index, str_start, str_end = 0, 0, 0, 0

index = 0
str_list = []

switch = 1 # script 제거하기 위한 스위치 / 1 - On , 0 - Off

for i in source:
    
    #인지 부분
    if i == '<':
        front_index = index + 1      # < > 안의 문자확인을 위한 인덱스 저장
        
        # script 를 만나면 스위치=0 OFF
        if source[front_index : front_index + 6] == 'script': switch = 0
        elif source[front_index : front_index + 5] == 'style': switch = 0
        
        
    elif i == '>':
        back_index = index       # < > 안의 문자확인을 위한 인덱스 저장
        
        # /script, /style를 만나면 스위치=1 ON
        if source[back_index - 8 : back_index + 1] == '</script>': switch = 1
        elif source[back_index - 7 : back_index + 1] == '</style>': switch = 1
        
        elif switch == 1 : str_start = back_index + 1
        # 스위치 ON 이고 '>'만났기에 문자열 시작으로 그 때의 인덱스 저장    
    
    
    if str_start != 0 and i == '<':  # 스위치 0n 이고 '<' 만나면
        str_end = index # 문자열 끝이므로 그 때의 인덱스 저장
        
        #삽입 부분
        if source[str_start : str_end] != '' and source[str_start : str_end] != ' ':  # 비어있는 값 삭제
            str_list.append(source[str_start : str_end]) # 시작 인덱스 ~ 끝 인덱스
        
        #초기화
        str_start = 0
        str_end = 0        
    
    index += 1

    
# 추가 부분 : &lt ~ &gt 도 없애기
for s in str_list:
    if '&lt' in s:
        str_list.remove(s)

# 요구사항 2, 3
import string

p_list = list(string.punctuation)



# 구두문자 제거 부분
for i in range(len(str_list)):
    str_list[i] = str_list[i].translate(str.maketrans('','', string.punctuation))
    
true_str =[]
f_index = 0
    
#텍스트 문자열 -> 순수 텍스트 문자열
for str1 in str_list:
    switch = 1
    for i in range(len(str1)):
        if switch != 0 and str1[i] != ' ':
            f_index = i
            switch = 0
        
        elif str1[i] == ' ':
            true_str.append(str1[f_index:i])
            switch = 1
            
        if i == len(str1) - 1:
            true_str.append(str1[f_index:i+1])

# 요구사항 4
str_dict = dict()

for i in range(len(true_str)):
    if true_str[i] not in str_dict: str_dict[true_str[i]] = 1
    else:
        str_dict[true_str[i]] = str_dict.get(true_str[i]) + 1
    
print(str_dict)
# Out:
# {'The': 40, 'New': 25, 'York': 19, 'Times': 18, 'Times ': 1, 'Breaking': 1, 'News': 4, 'US': 4, 'World': 2, 'and': 26, 'Videos': 1, 'Sections': 1, 'SEARCH': 1, 'Skip': 2, 'to': 51, 'content': 1, 'site': 1, 'index': 1, 'International': 2, 'Canada': 2, 'Español': 1, '中文': 1, 'Today’s': 1, 'Paper': 1, 'Politics': 1, 'NY': 1, 'Business': 1, 'Opinion': 3, 'Tech': 1, 'Science': 1, 'Health': 1, 'Sports': 1, 'Arts': 1, 'Books': 1, 'Style': 1, 'Food': 1, 'Travel': 1, 'Magazine': 2, 'T': 2, 'Real': 1, 'Estate': 1, 'Video': 1, 'With': 6, 'Coercion': 1, 'Black': 1, 'Boxes': 1, 'Russia': 2, 'Installs': 1, 'a': 34, 'Digital': 1, 'Iron': 1, 'Curtain': 1, 'Kremlin’s': 1, 'new': 2, 'censorship': 1, 'tools': 1, 'give': 2, 'it': 4, 'sweeping': 2, 'powers': 1, 'block': 1, 'slow': 1, 'down': 2, 'websites': 1, 'that': 10, 'does': 1, 'not': 1, 'want': 1, 'the': 74, 'Russian': 4, 'public': 1, 'see': 1, 'program': 1, 'quietly': 1, 'built': 1, 'over': 3, 'two': 2, 'years': 1, 'is': 12, 'start': 1, 'of': 35, '
# ...

# %% [markdown]
# ## cse.koreatech.ac.kr 은 서버가 닫혀서 소스를 못받아왔습니다.

# %% [markdown]
# [소감]
# 시간복잡도를 최소로하는게 가장 어려운 부분이었고, 7일전부터 했지만 아직 미숙한지 시간이 부족했습니다. 다음 과제는 더 완벽하게 하려고 노력하겠습니다.
#
# 감사합니다.
